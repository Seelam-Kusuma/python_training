# %%
import pandas as pd
bikes=pd.read_csv(r"C:\Users\Kusuma\Downloads\bikes.csv")
bikes
# Out:
#            Date Unnamed: 1  Berri1   CSC  Mais1  Mais2  Parc  PierDup  \
# 0    01/01/2013      00:00       0     0      1      0     6        0
# 1    02/01/2013      00:00      69     0     13      0    18        0
# 2    03/01/2013      00:00      69     2     21      6    22        1
# 3    04/01/2013      00:00      80     0     22      4    16        0
# 4    05/01/2013      00:00      52     4     19      3    12        0
# ..          ...        ...     ...   ...    ...    ...   ...      ...
# 256  14/09/2013      00:00    2488  1494   1706   2911   979     1075
# 257  15/09/2013      00:00    2243  1749   1417   2933  1804     1459
# 258  16/09/2013      00:00    4206  2466   2799   5485  3272      855
# 259  17/09/2013      00:00    5506  3153   3563   6626  3882     1485
# 260  18/09/2013      00:00    1564  3330   1154   1803  4074     1759
#
#      Rachel1  Totem_Laurier
# 0          1              0
# 1          2              0
# 2          0              0
# ...

# %%
bikes.head()
# Out:
#          Date Unnamed: 1  Berri1  CSC  Mais1  Mais2  Parc  PierDup  Rachel1  \
# 0  01/01/2013      00:00       0    0      1      0     6        0        1
# 1  02/01/2013      00:00      69    0     13      0    18        0        2
# 2  03/01/2013      00:00      69    2     21      6    22        1        0
# 3  04/01/2013      00:00      80    0     22      4    16        0      125
# 4  05/01/2013      00:00      52    4     19      3    12        0       97
#
#    Totem_Laurier
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0

# %%
bikes.describe()
# Out:
#             Berri1          CSC        Mais1        Mais2         Parc  \
# count   261.000000   261.000000   261.000000   261.000000   261.000000
# mean   2743.390805  1221.858238  1757.590038  3224.130268  1669.425287
# std    2247.957848  1070.037364  1458.793882  2589.514354  1363.738862
# min       0.000000     0.000000     1.000000     0.000000     6.000000
# 25%     392.000000    12.000000   236.000000   516.000000   222.000000
# 50%    2771.000000  1184.000000  1706.000000  3178.000000  1584.000000
# 75%    4767.000000  2168.000000  3158.000000  5812.000000  3068.000000
# max    6803.000000  3330.000000  4716.000000  7684.000000  4103.000000
#
#            PierDup      Rachel1  Totem_Laurier
# count   261.000000   261.000000     261.000000
# mean   1152.885057  3084.425287    1858.793103
# std    1208.848429  2380.255540    1434.899574
# min       0.000000     0.000000       0.000000
# 25%      12.000000   451.000000     340.000000
# ...

# %%
bikes['Date']=pd.to_datetime(bikes['Date'],format='%d/%m%y')
plt.figure(figsize=(18,12))
plt.plot(bikes['Date'],bikes['Berri1'],label='Berri1')
plt.plot(bikes['Date'],bikes['PierDup'],label='PierDup')
plt.xlabel('Date')
plt.ylabel('Attendance')
plt.title('Daily attedance of Berri1 and PierDup TRacks')
plt.show()

# %%
bikes['Weekday']=bikes['Date'].dt.weekday
bikes['Weekday_name']=bikes['Date'].dt.strftime('%A')
print(bikes.head())
# Out:
#         Date Unnamed: 1  Berri1  CSC  Mais1  Mais2  Parc  PierDup  Rachel1  \
# 0 2013-01-01      00:00       0    0      1      0     6        0        1
# 1 2013-02-01      00:00      69    0     13      0    18        0        2
# 2 2013-03-01      00:00      69    2     21      6    22        1        0
# 3 2013-04-01      00:00      80    0     22      4    16        0      125
# 4 2013-05-01      00:00      52    4     19      3    12        0       97
#
#    Totem_Laurier  Weekday Weekday_name
# 0              0      1.0      Tuesday
# 1              0      4.0       Friday
# 2              0      4.0       Friday
# 3              0      0.0       Monday
# 4              0      2.0    Wednesday

# %%
weekday_sum=bikes.groupby('Weekday_name').sum(numeric_only=True)
weekday_sum
# Out:
#               Berri1    CSC  Mais1  Mais2   Parc  PierDup  Rachel1  \
# Weekday_name
# Friday         43418  17920  26206  48169  23752    23546    51182
# Monday         42754  19719  27090  50069  26753    15709    47941
# Saturday       51628  24425  33849  62888  32155    19326    56876
# Sunday         43302  18502  26706  50018  25157    17800    49269
# Thursday       42016  19118  27778  51146  26465    12656    45186
# Tuesday        38284  16712  25666  47175  23259    14080    44355
# Wednesday      35099  16464  22453  42664  22474    14049    44118
#
#               Totem_Laurier  Weekday
# Weekday_name
# Friday                28811     64.0
# Monday                26134      0.0
# Saturday              34472     80.0
# Sunday                28810     90.0
# Thursday              26440     42.0
# Tuesday               26583     16.0
# Wednesday             24971     30.0

# %%
weekday_sum.plot(kind='bar',figsize=(10,10))
plt.title('Sum of Attedance by weekend')
plt.xlabel('weekday')
plt.ylabel('Total Attedance')
plt.show()

# %% [markdown]
# **federer.csv**

# %%
import pandas as pd
fed=pd.read_csv(r"C:\Users\Kusuma\Downloads\federer.csv")
fed.head()
# Out:
#    year           tournament  start date type        surface      draw  \
# 0  1998   Basel, Switzerland  05.10.1998   WS   Indoor: Hard  Draw: 32
# 1  1998     Toulouse, France  28.09.1998   WS   Indoor: Hard  Draw: 32
# 2  1998     Toulouse, France  28.09.1998   WS   Indoor: Hard  Draw: 32
# 3  1998     Toulouse, France  28.09.1998   WS   Indoor: Hard  Draw: 32
# 4  1998  Geneva, Switzerland  24.08.1998   CH  Outdoor: Clay  Draw: 32
#
#   atp points  atp ranking tournament prize money round  ...  \
# 0          1        396.0                 $9,800   R32  ...
# 1         59        878.0                $10,800   R32  ...
# 2         59        878.0                $10,800   R16  ...
# 3         59        878.0                $10,800     Q  ...
# 4          1        680.0                   $520   R32  ...
#
#   player2 2nd serve return points total player2 break points converted won  \
# 0                                  22.0                                4.0
# ...

# %%
fed
# Out:
#       year                  tournament  start date type        surface  \
# 0     1998          Basel, Switzerland  05.10.1998   WS   Indoor: Hard
# 1     1998            Toulouse, France  28.09.1998   WS   Indoor: Hard
# 2     1998            Toulouse, France  28.09.1998   WS   Indoor: Hard
# 3     1998            Toulouse, France  28.09.1998   WS   Indoor: Hard
# 4     1998         Geneva, Switzerland  24.08.1998   CH  Outdoor: Clay
# ...    ...                         ...         ...  ...            ...
# 1174  2012  Australian Open, Australia  16.01.2012   GS  Outdoor: Hard
# 1175  2012                 Doha, Qatar  02.01.2012  250  Outdoor: Hard
# 1176  2012                 Doha, Qatar  02.01.2012  250  Outdoor: Hard
# 1177  2012                 Doha, Qatar  02.01.2012  250  Outdoor: Hard
# 1178  2012                 Doha, Qatar  02.01.2012  250  Outdoor: Hard
#
#            draw atp points  atp ranking tournament prize money round  ...  \
# ...

# %%
fed.columns
# Out:
# Index(['year', 'tournament', 'start date', 'type', 'surface', 'draw',
#        'atp points', 'atp ranking', 'tournament prize money', 'round',
#        'opponent', 'ranking', 'score', 'stats link', 'tournament.1',
#        'tournament round', 'time', 'winner', 'player1 name',
#        'player1 nationality', 'player1 aces', 'player1 double faults',
#        'player1 1st serves in', 'player1 1st serves total',
#        'player1 1st serve points won', 'player1 1st serve points total',
#        'player1 2nd serve points won', 'player1 2nd serve points total',
#        'player1 break points won', 'player1 break points total',
#        'player1 service games played', 'player1 1st serve return points won',
#        'player1 1st serve return points total',
#        'player1 2nd serve return points won',
#        'player1 2nd serve return points total',
#        'player1 break points converted won',
#        'player1 break points converted total', 'player1 return games played',
# ...

# %%
matches_won = fed[fed['winner'] =='Roger Federer'].shape[0]
matches_won
total_matches = fed.shape[0]
win_percentage = (matches_won / total_matches) * 100
win_percentage
# Out:
# 82.44274809160305

# %%
faults=(fed['player1 double faults'])+(fed['player2 double faults'])
total_win=fed['player1 total points won']+fed['player2 total points won']
proportion=faults/total_win
proportion
# Out:
# 0       0.029126
# 1       0.000000
# 2       0.047297
# 3       0.053846
# 4            NaN
#           ...
# 1174    0.021739
# 1175    0.034884
# 1176    0.000000
# 1177    0.011561
# 1178         NaN
# Length: 1179, dtype: float64

# %%
average_wins = fed.groupby('surface')['player2 total points total'].mean()
average_wins
# Out:
# surface
# Indoor: Carpet    159.175439
# Indoor: Clay             NaN
# Indoor: Hard      142.871134
# Outdoor: Clay     164.523148
# Outdoor: Grass    180.106061
# Outdoor: Hard     161.133178
# Name: player2 total points total, dtype: float64

# %%
faults=(fed['player1 double faults'])+(fed['player2 double faults'])
total_win=fed['player1 total points won']+fed['player2 total points won']
fed['proportion']=faults/total_win
fed['proportion']
average_double_faults_in_year = fed.groupby('year')['proportion'].mean()
average_double_faults_in_year
# Out:
# C:\Users\Kusuma\AppData\Local\Temp\ipykernel_25824\2536166267.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   fed['proportion']=faults/total_win
# year
# 1998    0.031936
# 1999    0.043523
# 2000    0.042981
# 2001    0.043571
# 2002    0.035103
# 2003    0.042785
# 2004    0.029896
# 2005    0.030677
# 2006    0.026268
# 2007    0.025484
# 2008    0.025075
# 2009    0.029509
# 2010    0.024857
# 2011    0.026632
# 2012    0.027941
# Name: proportion, dtype: float64

# %% [markdown]
# **titanic.csv**

# %%
import pandas as pd
titanic_df=pd.read_csv(r"C:\Users\Kusuma\Downloads\ToBeShared (1)\ToBeShared\code\data\titanic_train.csv")
titanic_df
# Out:
#      survived  pclass                                               name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         sex   age  sibsp  parch            ticket     fare cabin embarked
# ...

# %%
titanic_df.columns
# Out:
# Index(['survived', 'pclass', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked'],
#       dtype='object')

# %%
titanic_df.groupby('sex')['survived'].count()
# Out:
# sex
# female    314
# male      577
# Name: survived, dtype: int64

# %%
titanic_df.groupby('pclass')['survived'].count()
# Out:
# pclass
# 1    216
# 2    184
# 3    491
# Name: survived, dtype: int64

# %%
titanic_df.groupby(['sex','pclass'])['survived'].mean() *100
# Out:
# sex     pclass
# female  1         96.808511
#         2         92.105263
#         3         50.000000
# male    1         36.885246
#         2         15.740741
#         3         13.544669
# Name: survived, dtype: float64
